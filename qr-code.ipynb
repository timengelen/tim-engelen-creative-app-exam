# %%
import segno

# %%
qrcode = segno.make_qr("https://youtube.com/shorts/Qi3yXm3V9Rw?feature=share")
qrcode

# %%
qrcode.save("../images/qrcode1.png")

# %%
qrcode.to_pil(scale=10,)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=370x370>

# %%
qrcode.save("../images/qrcode3.png")
